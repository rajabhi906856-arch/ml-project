# %% [markdown]
# <a href="https://colab.research.google.com/github/rajabhi906856-arch/ml-project/blob/main/network_intrusion_detection_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Network Intrusion Detection System (NIDS)**

# %%
# !pip install kaggle

# %%
# !pip install pandas numpy scikit-learn xgboost imbalanced-learn matplotlib seaborn

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# ### 1 .Project Setup

# %% [markdown]
# ####1.1. import libraries

# %%
import kagglehub
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ####1.2. mount google drive

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
save_path = "/content/drive/MyDrive/NIDS_Project/network_intrusion_combined.csv"

df.to_csv(save_path, index=False)

print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!

# %% [markdown]
# ###2 . Dataset Acquisition

# %% [markdown]
# ####2.1 Download Kaggle Dataset

# %%
import os
os.environ["KAGGLE_API_TOKEN"] = "export KAGGLE_API_TOKEN=KGAT_997484021e388dfbc7bccb81a15a3726"

# %%
import kagglehub
path = kagglehub.dataset_download("chethuhn/network-intrusion-dataset")
print("data downloaded to:",path)
# Out:
# ...
# 100%|██████████| 230M/230M [00:11<00:00, 20.5MB/s]
# Extracting files...
# data downloaded to: /root/.cache/kagglehub/datasets/chethuhn/network-intrusion-dataset/versions/1

# %%
path = kagglehub.dataset_download("chethuhn/network-intrusion-dataset")
print("Data downloaded to:", path)
# Out:
# Using Colab cache for faster access to the 'network-intrusion-dataset' dataset.
# Data downloaded to: /kaggle/input/network-intrusion-dataset

# %% [markdown]
# ###3 . Dataset Loading & Combining

# %%
print(os.listdir(path))
# Out:
# ['Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv', 'Tuesday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv', 'Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv', 'Wednesday-workingHours.pcap_ISCX.csv']

# %%
os.listdir(path)
# Out:
# ['Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv',
#  'Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv',
#  'Tuesday-WorkingHours.pcap_ISCX.csv',
#  'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv',
#  'Monday-WorkingHours.pcap_ISCX.csv',
#  'Friday-WorkingHours-Morning.pcap_ISCX.csv',
#  'Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv',
#  'Wednesday-workingHours.pcap_ISCX.csv']

# %%
import pandas as pd
import os

# Get all CSV files
csv_files = [f for f in os.listdir(path) if f.endswith(".csv")]

# Store individual DataFrames
dfs = []

# Load each CSV
for file in csv_files:
    print("Loading:", file)

    temp = pd.read_csv(os.path.join(path, file))

    # Remove leading/trailing spaces from column names
    temp.columns = temp.columns.str.strip()

    dfs.append(temp)

# Concatenate all CSV files
df = pd.concat(dfs, ignore_index=True)

print("\nNumber of CSV files loaded:", len(dfs))
print("Final shape:", df.shape)
# Out:
# Loading: Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv
# Loading: Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv
# Loading: Tuesday-WorkingHours.pcap_ISCX.csv
# Loading: Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv
# Loading: Monday-WorkingHours.pcap_ISCX.csv
# Loading: Friday-WorkingHours-Morning.pcap_ISCX.csv
# Loading: Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv
# Loading: Wednesday-workingHours.pcap_ISCX.csv
#
# Number of CSV files loaded: 8
# Final shape: (2830743, 79)

# %% [markdown]
# ###4 .Initial Data Exploration

# %%
df.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0                22        1266342                 41                      44
# 1                22        1319353                 41                      44
# 2                22            160                  1                       1
# 3                22        1303488                 41                      42
# 4             35396             77                  1                       2
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                         2664                         6954
# 1                         2664                         6954
# 2                            0                            0
# 3                         2728                         6634
# 4                            0                            0
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# ...

# %%
df.shape
# Out:
# (2830743, 79)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2830743 entries, 0 to 2830742
# Data columns (total 79 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Destination Port             int64
#  1   Flow Duration                int64
#  2   Total Fwd Packets            int64
#  3   Total Backward Packets       int64
#  4   Total Length of Fwd Packets  int64
#  5   Total Length of Bwd Packets  int64
#  6   Fwd Packet Length Max        int64
#  7   Fwd Packet Length Min        int64
#  8   Fwd Packet Length Mean       float64
#  9   Fwd Packet Length Std        float64
#  10  Bwd Packet Length Max        int64
#  11  Bwd Packet Length Min        int64
#  12  Bwd Packet Length Mean       float64
#  13  Bwd Packet Length Std        float64
#  14  Flow Bytes/s                 float64
#  15  Flow Packets/s               float64
#  16  Flow IAT Mean                float64
#  17  Flow IAT Std                 float64
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Destination Port', 'Flow Duration', 'Total Fwd Packets', 'Total Backward Packets', 'Total Length of Fwd Packets', 'Total Length of Bwd Packets', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Fwd Packet Length Mean', 'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length', 'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s', 'Min Packet Length', 'Max Packet Length', 'Packet Length Mean', 'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count', 'URG Flag Count', 'CWE Flag Count', 'ECE Flag Cou
# ...

# %%
print(df["Label"].value_counts())
# Out:
# Label
# BENIGN                        2273097
# DoS Hulk                       231073
# PortScan                       158930
# DDoS                           128027
# DoS GoldenEye                   10293
# FTP-Patator                      7938
# SSH-Patator                      5897
# DoS slowloris                    5796
# DoS Slowhttptest                 5499
# Bot                              1966
# Web Attack � Brute Force         1507
# Web Attack � XSS                  652
# Infiltration                       36
# Web Attack � Sql Injection         21
# Heartbleed                         11
# Name: count, dtype: int64

# %%
df.columns = df.columns.str.strip()

# %%
for col in df.columns:
    if col != col.strip():
        print(f"Whitespace issue: '{col}'")

# %%
df['Flow Duration']
# Out:
# 0          1266342
# 1          1319353
# 2              160
# 3          1303488
# 4               77
#             ...
# 2830738      32215
# 2830739        324
# 2830740         82
# 2830741    1048635
# 2830742      94939
# Name: Flow Duration, Length: 2830743, dtype: int64

# %%
print("Number of CSVs loaded:", len(df))
# Out:
# Number of CSVs loaded: 2830743

# %%
print("Number of CSVs loaded:", len(dfs))
# Out:
# Number of CSVs loaded: 8

# %%
df.shape
# Out:
# (2830743, 79)

# %%
print("Final shape:", df.shape)
# Out:
# Final shape: (2830743, 79)

# %%
import os

project_path = "/content/drive/MyDrive/NIDS_Project"

os.makedirs(project_path, exist_ok=True)

print("Folder created:", project_path)
# Out:
# Folder created: /content/drive/MyDrive/NIDS_Project

# %%
import os

print(os.path.exists(save_path))
# Out:
# True

# %%
df.isnull().sum()
# Out:
# Destination Port               0
# Flow Duration                  0
# Total Fwd Packets              0
# Total Backward Packets         0
# Total Length of Fwd Packets    0
#                               ..
# Idle Mean                      0
# Idle Std                       0
# Idle Max                       0
# Idle Min                       0
# Label                          0
# Length: 79, dtype: int64

# %%
df.dtypes
# Out:
# Destination Port                 int64
# Flow Duration                    int64
# Total Fwd Packets                int64
# Total Backward Packets           int64
# Total Length of Fwd Packets      int64
#                                 ...
# Idle Mean                      float64
# Idle Std                       float64
# Idle Max                         int64
# Idle Min                         int64
# Label                           object
# Length: 79, dtype: object

# %%
df.describe()
# Out:
#        Destination Port  Flow Duration  Total Fwd Packets  \
# count      2.830743e+06   2.830743e+06       2.830743e+06
# mean       8.071483e+03   1.478566e+07       9.361160e+00
# std        1.828363e+04   3.365374e+07       7.496728e+02
# min        0.000000e+00  -1.300000e+01       1.000000e+00
# 25%        5.300000e+01   1.550000e+02       2.000000e+00
# 50%        8.000000e+01   3.131600e+04       2.000000e+00
# 75%        4.430000e+02   3.204828e+06       5.000000e+00
# max        6.553500e+04   1.200000e+08       2.197590e+05
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# count            2.830743e+06                 2.830743e+06
# mean             1.039377e+01                 5.493024e+02
# std              9.973883e+02                 9.993589e+03
# min              0.000000e+00                 0.000000e+00
# 25%              1.000000e+00                 1.200000e+01
# 50%              2.000000e+00                 6.200000e+01
# ...

# %% [markdown]
# ###5 .Data cleaning

# %%
import numpy as np
np.isinf(df.select_dtypes(include= np.number)).sum()
# Out:
# Destination Port               0
# Flow Duration                  0
# Total Fwd Packets              0
# Total Backward Packets         0
# Total Length of Fwd Packets    0
#                               ..
# Active Min                     0
# Idle Mean                      0
# Idle Std                       0
# Idle Max                       0
# Idle Min                       0
# Length: 78, dtype: int64

# %%
num_cols=df.select_dtypes(include=np.number).columns
neg_counts=(df[num_cols]<0).sum()
print(neg_counts)
# Out:
# Destination Port                 0
# Flow Duration                  115
# Total Fwd Packets                0
# Total Backward Packets           0
# Total Length of Fwd Packets      0
#                               ...
# Active Min                       0
# Idle Mean                        0
# Idle Std                         0
# Idle Max                         0
# Idle Min                         0
# Length: 78, dtype: int64

# %%
df[df['Flow Duration'] < 0]['Flow Duration']
# Out:
# 47878     -1
# 61031     -1
# 61927     -1
# 86737     -1
# 90372     -1
#           ..
# 2678632   -1
# 2742850   -1
# 2743589   -1
# 2777786   -1
# 2794659   -1
# Name: Flow Duration, Length: 115, dtype: int64

# %%
df['Flow Duration'].min()
# Out:
# -13

# %%
df['Flow Duration'].max()
# Out:
# 119999998

# %%
df.loc[df['Flow Duration'] < 0, 'Flow Duration'].value_counts().sort_index()
# Out:
# Flow Duration
# -13      1
# -12      2
# -4       1
# -2       2
# -1     109
# Name: count, dtype: int64

# %%
df[df['Flow Duration'] < 0]['Label'].value_counts()
# Out:
# Label
# BENIGN    115
# Name: count, dtype: int64

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

save_path = "/content/drive/MyDrive/NIDS_Project/network_intrusion_combined.csv"

df = pd.read_csv(save_path)

# %%
df = df[df['Flow Duration'] >= 0].copy()

# %%
df.loc[df['Flow Duration'] < 0, 'Flow Duration'].value_counts().sort_index()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.duplicated().sum()
# Out:
# np.int64(308381)

# %%
# How many duplicates per class?
dupe_rows = df[df.duplicated(keep=False)]
print(dupe_rows['Label'].value_counts())
# Out:
# Label
# BENIGN                      236257
# PortScan                    101501
# DoS Hulk                     59564
# SSH-Patator                   2826
# FTP-Patator                   2457
# DoS slowloris                  507
# DoS Slowhttptest               323
# Web Attack � Brute Force        62
# DDoS                            20
# Bot                             19
# DoS GoldenEye                   14
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (2830743, 79)

# %%
df=df.drop_duplicates()

# %%
print("After:", df.shape)
# Out:
# After: (2522362, 79)

# %%
print(df['Label'].value_counts())
# Out:
# Label
# BENIGN                        2096484
# DoS Hulk                       172849
# DDoS                           128016
# PortScan                        90819
# DoS GoldenEye                   10286
# FTP-Patator                      5933
# DoS slowloris                    5385
# DoS Slowhttptest                 5228
# SSH-Patator                      3219
# Bot                              1953
# Web Attack � Brute Force         1470
# Web Attack � XSS                  652
# Infiltration                       36
# Web Attack � Sql Injection         21
# Heartbleed                         11
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes.value_counts()
# Out:
# int64      54
# float64    24
# object      1
# Name: count, dtype: int64

# %%
df.nunique().sort_values()
# Out:
# Bwd PSH Flags                 1
# Fwd Avg Bulk Rate             1
# Bwd Avg Bytes/Bulk            1
# Bwd Avg Packets/Bulk          1
# Fwd Avg Packets/Bulk          1
#                          ...
# Bwd Packets/s           1107886
# Flow IAT Mean           1166311
# Fwd Packets/s           1220423
# Flow Packets/s          1240164
# Flow Bytes/s            1593908
# Length: 79, dtype: int64

# %%
print(df['Label'].isnull().sum())
print(df['Label'].nunique())
print(df['Label'].value_counts())
# Out:
# 0
# 15
# Label
# BENIGN                        2096484
# DoS Hulk                       172849
# DDoS                           128016
# PortScan                        90819
# DoS GoldenEye                   10286
# FTP-Patator                      5933
# DoS slowloris                    5385
# DoS Slowhttptest                 5228
# SSH-Patator                      3219
# Bot                              1953
# Web Attack � Brute Force         1470
# Web Attack � XSS                  652
# Infiltration                       36
# Web Attack � Sql Injection         21
# Heartbleed                         11
# Name: count, dtype: int64

# %%
constant_cols = [col for col in df.columns if df[col].nunique() <= 1]

print("Number of constant columns:", len(constant_cols))
print(constant_cols)
# Out:
# Number of constant columns: 8
# ['Bwd PSH Flags', 'Bwd URG Flags', 'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk', 'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate']

# %%
df = df.drop(columns=constant_cols)

# %%
print("removed:", len(constant_cols))
print("remaining:", df.shape)
# Out:
# removed: 8
# remaining: (2522362, 71)
